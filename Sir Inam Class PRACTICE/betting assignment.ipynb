# %%
import random
while True:
#     num=random.randint(0,30)
    num=0
    print(num)                                      #REMOVE IT LATER
    payout=0
    
    amount=int(input("Enter Betting Amount Between 1-10: "))
    if amount <1 or amount>10:
        print("\nBetting should be 1-10.")
        break
#         raise ValueError("Betting should be 1-10")

    guess=int(input("Enter Your Guess: "))
    if guess < 0 or guess>30:
        print("\nInvalid guess.")
        break
#         raise ValueError("Out Of Range")
        
    if guess==num:
        print("\nCorrect Guess")
        print()
        if num==0 or num==1:
            None
        else:
            if num%2==0:
                amount*=2
                print("\nCongrats It's Even Number, You Got 2X Reward.")
        
        
        if num==0:
            None
        else:
            if num%10==0:
                amount*=3
                print("\nCongrats It's Multiple Number, You Got 3X Reward.")
        
    
        if num<5:
            amount*=2
            print("\nCongrats The Number Is Below 5, You Got 2X Reward.")
        
        count=2
        prime=True
        if num==0 or num==1:
            None
#         print("neiter prime nor composite")
        else:
            while count<num:
                if num%count==0:
                    prime=False
                    break
            
                count+=1
            if prime==True:
                amount*=5
                print("\nCongrats The Number Is Prime, You Got 5X Reward.")
            
        
     
        print("\nTotal Payout Amount: ",amount)
        payout=amount
        if payout<=0:
            print("\nSorry You Have No Money Left For Betting. Add Some More Money.")
        
    
        loop=input("\nDo You Want To Play Again: ")
        if loop =="yes" or loop =="YES":      
            continue
        else:
            break
    else:
        print("\nIncorrect Guess")
        break
# Out:
# 0
# Enter Betting Amount Between 1-10: 5
# Enter Your Guess: 0
#
# Correct Guess
#
#
# Congrats The Number Is Below 5, You Got 2X Reward.
#
# Total Payout Amount:  10
