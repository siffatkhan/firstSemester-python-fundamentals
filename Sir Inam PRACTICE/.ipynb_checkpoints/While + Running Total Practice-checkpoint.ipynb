# %%
count=1
total=0
while count<=5:
    print("Enter subject-",count,"marks: ")
    marks=int(input())
    total+=marks
    count+=1
    
avg=total/5
print("Total marks: ",total)
print("Average marks: ",avg)
# Out:
# Enter subject- 1 marks:
# 29
# Enter subject- 2 marks:
# 30
# Enter subject- 3 marks:
# 31
# Enter subject- 4 marks:
# 21
# Enter subject- 5 marks:
# 35
# Total marks:  146
# Average marks:  29.2

# %%
count=1
#total=total1=total2=0
#total,total1,total2=0,0,0
total=0
total1=0
total2=0
while count<=5:
    print("Enter subject-",count,"marks: ")
    marks=int(input())
    if count<=2:
        total1+=marks
    else:
        total2+=marks
        
    total+=marks
    count+=1
    
avg1=total1/2
avg2=total2/3
        
avg=(total1+total2)/5

print("Total marks: ",total)
print("Average marks: ",avg)
print("Average marks of first two paper: ",avg1)
print("Average marks of last three paper: ",avg2)
# Out:
# Enter subject- 1 marks:
# 30
# Enter subject- 2 marks:
# 30
# Enter subject- 3 marks:
# 20
# Enter subject- 4 marks:
# 20
# Enter subject- 5 marks:
# 20
# Total marks:  120
# Average marks:  24.0
# Average marks of first two paper:  30.0
# Average marks of last three paper:  20.0

# %%
count=1
#Q1=Q2=Q3=Q4=0
#Q1,Q2,Q3,Q4=0,0,0,0
total1=0
total2=0
total3=0
total4=0
while count<=12:
    print("Enter",count,"months rainfall")
    rainfall=float(input())
    if count<=3:
        total1+=rainfall
    elif count<=6:
        total2+=rainfall
    elif count<=9:
        total3+=rainfall
    else:
        total4+=rainfall
    
    count+=1
    
    
avg1=total1/3
avg2=total2/3
avg3=total3/3
avg4=total4/3
    
print("1st quarter rainfall average: ",avg1)
print("2nd quarter rainfall average: ",avg2)
print("3rd quarter rainfall average: ",avg3)
print("4th quarter rainfall average: ",avg4)

print("--------------------------------------")

       
if avg1<avg2 and avg1<avg3 and avg1<avg4:
     print("1st quarter is lowest.")
elif avg2<avg1 and avg2<avg3 and avg2<avg4:
     print("2nd quarter is lowest.")
elif avg3<avg1 and avg3<avg2 and avg3<avg4:
     print("3rd quarter is lowest.")
elif avg4<avg1 and avg4<avg2 and avg4<avg3:
     print("4th quarter is lowest.")
        
if avg1>avg2 and avg1>avg3 and avg1>avg4 :
     print("1st quarter is greatest.")
elif avg2>avg1 and avg2>avg3 and avg2>avg4:
     print("2nd quarter is greatest.")
elif avg3>avg1 and avg3>avg2 and avg3>avg4:
     print("3rd quarter is greatest.")
elif avg4>avg1 and avg4>avg2 and avg4>avg3:
     print("4th quarter is greatest.")

#THROUGH FUNCTON

# def islesser (a,b,c,d):
#     if a < b and a < c and a<d:
#         print("first quarter is lowest")
#     elif b < a and b < c and b<d:
#         print("2nd quarter is lowest")
#     elif c < a and c < b and c<d:
#         print("3rd quarter is lowest")
#     elif d < b and d < c and d<a:
#         print("forth quarter is lowest")
    
# def isgreater (a,b,c,d):
#     if a > b and a>c and a>d:
#         print("first quarter is greatest")
#     elif b > a and b > c and b>d:  
#         print("second quarter is greatest")
#     elif c > a and c > b and c>d:
#         print("3rd quarter is greatest")
#     elif d > b and d > c and d>a:
#         print("forth quarter is greatest")


# a=avg1
# b=avg2
# c=avg3
# d=avg4

# islesser(a,b,c,d)
# isgreater(a,b,c,d)


# a=40
# b=30
# c=100
# d=5
# islesser(a,b,c,d)
# isgreater(a,b,c,d)
# Out:
# Enter 1 months rainfall
# 10
# Enter 2 months rainfall
# 10
# Enter 3 months rainfall
# 10
# Enter 4 months rainfall
# 20
# Enter 5 months rainfall
# 30
# Enter 6 months rainfall
# 40
# Enter 7 months rainfall
# 70
# Enter 8 months rainfall
# 45
# Enter 9 months rainfall
# 65
# Enter 10 months rainfall
# 34
# Enter 11 months rainfall
# 87
# Enter 12 months rainfall
# 56
# first quarter is lowest
# 3rd quarter is greatest
# forth quarter is lowest
# 3rd quarter is greatest

# %%
#USING LISTS IN IT 
count=0
total=0
subj=['Programming','Mathematics','physics','ICT','PS']
while count<5:
    print("Enter ",subj[count],"marks: ")
    marks=int(input())
    total+=marks
    count+=1
    
avg=total/5
print("Total marks: ",total)
print("Average marks: ",avg)
# Out:
# Enter  Programming marks:
# 25
# Enter  Mathematics marks:
# 20
# Enter  physics marks:
# 21
# Enter  ICT marks:
# 22
# Enter  PS marks:
# 27
# Total marks:  115
# Average marks:  23.0
