# %%
from tkinter import *
root=Tk()
root.geometry("350x500")
root.title("Calculator By Siffat")
root.minsize(350,500)
root.maxsize(350,500)
frame=Frame(root,borderwidth=5,bg="yellow",relief=SUNKEN)
frame.pack(side=LEFT,anchor="nw")

root.mainloop()

# %%
from tkinter import *

def click(event):
    global stringvalue
    text=event.widget.cget("text")
    if text=="=":
        if stringvalue.get().isdigit():
            value=int(stringvalue.get())
        else:
            try:
                value=eval(screen.get())
            except Exception as e:
                value="Error"
                
            
        stringvalue.set(value)
        screen.update()
    elif text=="C":
        stringvalue.set("")
        screen.update()
        
    elif text=="←":
        pass
    else:
        stringvalue.set(stringvalue.get()+text)
        screen.update()
        
        

root=Tk()
root.geometry("380x530")
root.title("Calculator By Siffat")
# root.minsize(350,500)
# root.maxsize(350,500)

stringvalue=StringVar()
stringvalue.set("")
screen=Entry(root,textvar=stringvalue,font="lucida 60")
screen.pack(fill=X, ipadx=20, pady=20, padx=10)


frame1=Frame(root, bg="yellow")
button=Button(frame1,text="C", padx=8, pady=10,font="lucida 35 bold")
button.pack(side=LEFT,padx=5, pady=5)
button.bind("<Button-1>",click)
button=Button(frame1,text="←", padx=5, pady=10,font="lucida 35 bold")
button.pack(side=LEFT,padx=5, pady=5)
button.bind("<Button-1>",click)
button=Button(frame1,text="%", padx=5, pady=10,font="lucida 35 bold")
button.pack(side=LEFT,padx=5, pady=5)
button.bind("<Button-1>",click)
button=Button(frame1,text="/", padx=12, pady=10,font="lucida 35 bold")
button.pack(side=LEFT,padx=5, pady=5)
button.bind("<Button-1>",click)
frame1.pack()



frame1=Frame(root, bg="yellow")
button=Button(frame1,text="7", padx=10, pady=10,font="lucida 35 bold")
button.pack(side=LEFT,padx=5, pady=5)
button.bind("<Button-1>",click)
button=Button(frame1,text="8", padx=10, pady=10,font="lucida 35 bold")
button.pack(side=LEFT,padx=5, pady=5)
button.bind("<Button-1>",click)
button=Button(frame1,text="9", padx=10, pady=10,font="lucida 35 bold")
button.pack(side=LEFT,padx=5, pady=5)
button.bind("<Button-1>",click)
button=Button(frame1,text="*", padx=10, pady=10,font="lucida 35 bold")
button.pack(side=LEFT,padx=5, pady=5)
button.bind("<Button-1>",click)
frame1.pack()


frame1=Frame(root, bg="yellow")
button=Button(frame1,text="4", padx=8, pady=10,font="lucida 35 bold")
button.pack(side=LEFT,padx=5, pady=5)
button.bind("<Button-1>",click)
button=Button(frame1,text="5", padx=10, pady=10,font="lucida 35 bold")
button.pack(side=LEFT,padx=5, pady=5)
button.bind("<Button-1>",click)
button=Button(frame1,text="6", padx=10, pady=10,font="lucida 35 bold")
button.pack(side=LEFT,padx=5, pady=5)
button.bind("<Button-1>",click)
button=Button(frame1,text="-", padx=11, pady=10,font="lucida 35 bold")
button.pack(side=LEFT,padx=5, pady=5)
button.bind("<Button-1>",click)
frame1.pack()


frame1=Frame(root, bg="yellow")
button=Button(frame1,text="1", padx=11, pady=10,font="lucida 35 bold")
button.pack(side=LEFT,padx=5, pady=5)
button.bind("<Button-1>",click)
button=Button(frame1,text="2", padx=10, pady=10,font="lucida 35 bold")
button.pack(side=LEFT,padx=5, pady=5)
button.bind("<Button-1>",click)
button=Button(frame1,text="3", padx=10, pady=10,font="lucida 35 bold")
button.pack(side=LEFT,padx=5, pady=5)
button.bind("<Button-1>",click)
button=Button(frame1,text="+", padx=7, pady=10,font="lucida 35 bold")
button.pack(side=LEFT,padx=5, pady=5)
button.bind("<Button-1>",click)
frame1.pack()


frame1=Frame(root, bg="yellow")
button=Button(frame1,text="00", padx=0, pady=10,font="lucida 35 bold")
button.pack(side=LEFT,padx=5, pady=5)
button.bind("<Button-1>",click)
button=Button(frame1,text="0", padx=8, pady=10,font="lucida 35 bold")
button.pack(side=LEFT,padx=5, pady=5)
button.bind("<Button-1>",click)
button=Button(frame1,text=".", padx=15, pady=10,font="lucida 35 bold")
button.pack(side=LEFT,padx=5, pady=5)
button.bind("<Button-1>",click)
button=Button(frame1,text="=", padx=7, pady=10,font="lucida 35 bold")
button.pack(side=LEFT,padx=5, pady=5)
button.bind("<Button-1>",click)
frame1.pack()


root.mainloop()

# %%
import tkinter as tk

class Calculator(tk.Tk):
    def __init__(self):
        super().__init__()

        self.title("Calculator")
        self.geometry("400x400")

        self.result_var = tk.StringVar()

        self.create_widgets()

    def create_widgets(self):
        # Entry to display the result
        entry = tk.Entry(self, textvariable=self.result_var, font=("Arial", 24), bd=10)
        entry.grid(row=0, column=0, columnspan=4)

        # Buttons for numbers and operators
        buttons = [
            ("7", 1, 0), ("8", 1, 1), ("9", 1, 2), ("/", 1, 3),
            ("4", 2, 0), ("5", 2, 1), ("6", 2, 2), ("*", 2, 3),
            ("1", 3, 0), ("2", 3, 1), ("3", 3, 2), ("-", 3, 3),
            ("0", 4, 0), (".", 4, 1), ("+", 4, 2), ("=", 4, 3),
        ]

        for (text, row, col) in buttons:
            button = tk.Button(self, text=text, font=("Arial", 18), width=5, height=2, command=lambda t=text: self.on_button_click(t))
            button.grid(row=row, column=col)

    def on_button_click(self, text):
        if text == "=":
            try:
                expression = self.result_var.get()
                result = eval(expression)
                self.result_var.set(result)
            except:
                self.result_var.set("Error")
        else:
            current_text = self.result_var.get()
            new_text = current_text + text
            self.result_var.set(new_text)

if __name__ == "__main__":
    app = Calculator()
    app.mainloop()
